# %% [markdown]
# <a href="https://colab.research.google.com/github/Anisha2810/Neural-networks-and-deep-learning/blob/main/VGG_OR_Resnet_with_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# -----------------------------
# VGG-like CNN Model
# -----------------------------
class VGG(nn.Module):
    def __init__(self, num_classes=10):
        super(VGG, self).__init__()

        self.features = nn.Sequential(
            # Block 1
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            # Block 2
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            # Block 3
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(256 * 4 * 4, 512),  # depends on input size (32x32)
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# -----------------------------
# Example Usage
# -----------------------------
if __name__ == "__main__":
    model = VGG(num_classes=10)

    # Dummy input (batch_size=8, 3 channels, 32x32 image)
    x = torch.randn(8, 3, 32, 32)

    output = model(x)
    print("Output shape:", output.shape)

    # Training setup
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    labels = torch.randint(0, 10, (8,))

    loss = criterion(output, labels)
    loss.backward()
    optimizer.step()

    print("Loss:", loss.item())
# Out:
# Output shape: torch.Size([8, 10])
# Loss: 2.295687198638916
